# %%
import json
import csv
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Dropout, Embedding

# %% [markdown]
# ## Loading dataset and preprocessing

# %%
def load_data(json_file):
    f = open(json_file)
    data = json.load(f)
    
    texts = []
    for i in range(len(data['stories'])):
        text = data['stories'][i]['story']
        text.append('|')
        texts += text

    texts = ' '.join(texts).strip()
    return texts

# %%
filename = '../input/aesop-fables-dataset/Aesop Fables.json'
texts = load_data(filename)
texts
# Out:
# "There was once a little Kid whose growing horns made him think he was a grown-up Billy Goat and able to take care of himself. So one evening when the flock started home from the pasture and his mother called, the Kid paid no heed and kept right on nibbling the tender grass. A little later when he lifted his head, the flock was gone. He was all alone. The sun was sinking. Long shadows came creeping over the ground. A chilly little wind came creeping with them making scary noises in the grass. The Kid shivered as he thought of the terrible Wolf. Then he started wildly over the field, bleating for his mother. But not half-way, near a clump of trees, there was the Wolf! The Kid knew there was little hope for him. Please, Mr. Wolf, he said trembling, I know you are going to eat me. But first please pipe me a tune, for I want to dance and be merry as long as I can. The Wolf liked the idea of a little music before eating, so he struck up a merry tune and the Kid leaped and frisked gaily. Meanwhile, the flock was moving slowly homeward. In the still evening air the Wolf's piping carried far. The Shepherd Dogs pricked up their ears. They recognized the song the Wolf sings before a feast, and in a moment they were racing back to the pasture. The Wolf's song ended suddenly, and as he ran, with the Dogs at his heels, he called himself a fool for turning piper to please a Kid, when he should have stuck to his butcher's trade. | The Tortoise, you know, carries his house on his back. No matter how hard he tries, he cannot leave home. They say that Jupiter punished him so, because he was such a lazy stay-at-home that he would not go to Jupiters wedding, even when especially invited. After many years, Tortoise began to wish he had gone to that wedding. When he saw how gaily the birds flew about and how the Hare and the Chipmunk and all the other animals ran nimbly by, always eager to see everything there was to be seen, the Tortoise felt very sad and discontented. He wanted to see the world too, and there he was with a house on his back and little short legs that could hardly drag him along. One day he met a pair of Ducks and told them all his trouble. We can help you to see the world, said the Ducks. Take hold of this stick with your teeth and we will carry you far up in the air where you can see the whole countryside. But keep quiet or you will be sorry. The Tortoise was very glad indeed. He seized the stick firmly with his teeth, the two Ducks took hold of it one at each end, and away they sailed up toward the clouds. Just then a Crow flew by. He was very much astonished at the strange sight and cried: This must surely be the King of Tortoises! Why certainly began the Tortoise. But as he opened his mouth to say these foolish words he lost his hold on the stick, and down he fell to the ground, where he was dashed to pieces on a rock. | Why in the world do you walk sideways like that? said a Mother Crab to her son. You should always walk straight forward with your toes turned out. Show me how to walk, mother dear, answered the little Crab obediently, I want to learn. So the old Crab tried and tried to walk straight forward. But she could walk sideways only, like her son. And when she wanted to turn her toes out she tripped and fell on her nose. | An Ox came down to a reedy pool to drink. As he splashed heavily into the water, he crushed a young Frog into the mud. The old Frog soon missed the little one and asked his brothers and sisters what had become of him. A great big monster, said one of them, stepped on little brother with one of his huge feet! Big, was he! said the old Frog, puffing herself up. Was he as big as this? Oh, much bigger! they cried. The Frog puffed up still more. He could not have been bigger than this, she said. But the little Frogs all declared that the monster was much, much bigger and the old Frog kept puffing herself out more and more until, all at once, she burst. | A Dog and a Cock, who were the best of friends, wi ...

# %% [markdown]
# ## Converting all words to lowercase

# %%
def preprocess(texts):
    # Convert all words into lowercase
    texts = texts.lower()
    # Separating punctuations
    texts = word_tokenize(texts)  
    # Punctuations are thought as a word (written with space)
    texts = ' '.join(texts)  
    return texts

# %%
texts = preprocess(texts)
texts
# Out:
# "there was once a little kid whose growing horns made him think he was a grown-up billy goat and able to take care of himself . so one evening when the flock started home from the pasture and his mother called , the kid paid no heed and kept right on nibbling the tender grass . a little later when he lifted his head , the flock was gone . he was all alone . the sun was sinking . long shadows came creeping over the ground . a chilly little wind came creeping with them making scary noises in the grass . the kid shivered as he thought of the terrible wolf . then he started wildly over the field , bleating for his mother . but not half-way , near a clump of trees , there was the wolf ! the kid knew there was little hope for him . please , mr. wolf , he said trembling , i know you are going to eat me . but first please pipe me a tune , for i want to dance and be merry as long as i can . the wolf liked the idea of a little music before eating , so he struck up a merry tune and the kid leaped and frisked gaily . meanwhile , the flock was moving slowly homeward . in the still evening air the wolf 's piping carried far . the shepherd dogs pricked up their ears . they recognized the song the wolf sings before a feast , and in a moment they were racing back to the pasture . the wolf 's song ended suddenly , and as he ran , with the dogs at his heels , he called himself a fool for turning piper to please a kid , when he should have stuck to his butcher 's trade . | the tortoise , you know , carries his house on his back . no matter how hard he tries , he can not leave home . they say that jupiter punished him so , because he was such a lazy stay-at-home that he would not go to jupiters wedding , even when especially invited . after many years , tortoise began to wish he had gone to that wedding . when he saw how gaily the birds flew about and how the hare and the chipmunk and all the other animals ran nimbly by , always eager to see everything there was to be seen , the tortoise felt very sad and discontented . he wanted to see the world too , and there he was with a house on his back and little short legs that could hardly drag him along . one day he met a pair of ducks and told them all his trouble . we can help you to see the world , said the ducks . take hold of this stick with your teeth and we will carry you far up in the air where you can see the whole countryside . but keep quiet or you will be sorry . the tortoise was very glad indeed . he seized the stick firmly with his teeth , the two ducks took hold of it one at each end , and away they sailed up toward the clouds . just then a crow flew by . he was very much astonished at the strange sight and cried : this must surely be the king of tortoises ! why certainly began the tortoise . but as he opened his mouth to say these foolish words he lost his hold on the stick , and down he fell to the ground , where he was dashed to pieces on a rock . | why in the world do you walk sideways like that ? said a mother crab to her son . you should always walk straight forward with your toes turned out . show me how to walk , mother dear , answered the little crab obediently , i want to learn . so the old crab tried and tried to walk straight forward . but she could walk sideways only , like her son . and when she wanted to turn her toes out she tripped and fell on her nose . | an ox came down to a reedy pool to drink . as he splashed heavily into the water , he crushed a young frog into the mud . the old frog soon missed the little one and asked his brothers and sisters what had become of him . a great big monster , said one of them , stepped on little brother with one of his huge feet ! big , was he ! said the old frog , puffing herself up . was he as big as this ? oh , much bigger ! they cried . the frog puffed up still more . he could not have been bigger than this , she said . but the little frogs all declared that the monster was much , much bigger and the old frog kept puffing herself o ...

# %% [markdown]
# ## Converting all words to integer

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts([texts])
tokenized_texts = tokenizer.texts_to_sequences([texts])

# %%
tokenized_texts
# Out:
# [[48,
#   11,
#   102,
#   4,
#   93,
#   221,
#   450,
#   1134,
#   257,
#   79,
#   24,
#   172,
#   7,
#   11,
#   4,
#   1676,
#   1677,
#   167,
#   5,
#   349,
#   6,
#   125,
#   280,
#   8,
#   86,
#   3,
#   26,
#   28,
#   222,
#   32,
#   1,
#   237,
#   401,
#   126,
#   44,
#   1,
#   281,
#   5,
#   9,
#   152,
#   186,
#   2,
#   1,
#   221,
#   856,
#   63,
#   1135,
#   5,
#   223,
#   224,
#   29,
#   857,
#   1,
#   585,
#   503,
#   3,
#   4,
#   93,
#   350,
#   32,
#   7,
#   1136,
#   9,
#   98,
#   2,
#   1,
#   237,
#   11,
#   312,
#   3,
#   7,
#   11,
#   33,
#   858,
#   3,
#   1,
#   203,
#   11,
#   1137,
#   3,
#   107,
#   692,
#   84,
#   859,
#   153,
#   1,
#   258,
#   3,
#   4,
#   1678,
#   93,
#   282,
#   84,
#   859,
#   18,
#   42,
#   283,
#   1679,
#   1680,
#   10,
#   1,
#   503,
#   3,
#   1,
#   221,
#   1681,
#   19,
#   7,
#   154,
#   8,
#   1,
#   586,
#   38,
#   3,
#   51,
#   7,
#   401,
#   1138,
#   153,
#   1,
#   181,
#   2,
#   1682,
#   21,
#   9,
#   152,
#   3,
#   17,
#   23,
#   1683,
#   2,
#   127,
#   4,
#   1684,
#   8,
#   1139,
#   2,
#   48,
#   11,
#   1,
#   38,
#   31,
#   1,
#   221,
#   187,
#   48,
#   11,
#   93,
#   1140,
#   21,
#   24,
#   3,
#   168,
#   2,
#   451,
#   38,
#   2,
#   7,
#   30,
#   860,
#   2,
#   16,
#   108,
#   12,
#   80,
#   284,
#   6,
#   115,
#   50,
#   3,
#   17,
#   161,
#   168,
#   1141,
#   50,
#   4,
#   861,
#   2,
#   21,
#   16,
#   504,
#   6,
#   452,
#   5,
#   41,
#   1142,
#   19,
#   107,
#   19,
#   16,
#   85,
#   3,
#   1,
#   38,
#   1685,
#   1,
#   453,
#   8,
#   4,
#   93,
#   862,
#   112,
#   587,
#   2,
#   26,
#   7,
#   454,
#   34,
#   4,
#   1142,
#   861,
#   5,
#   1,
#   221,
#   863,
#   5,
#   1686,
#   1143,
#   3,
#   1144,
#   2,
#   1,
#   237,
#   11,
#   1687,
#   505,
#   693,
#   3,
#   10,
#   1,
#   204,
#   222,
#   455,
#   1,
#   38,
#   40,
#   1688,
#   313,
#   155,
#   3,
#   1,
#   132,
#   205,
#   1145,
#   34,
#   52,
#   456,
#   3,
#   20,
#   1689,
#   1,
#   402,
#   1,
#   38,
#   1146,
#   112,
#   4,
#   351,
#   2,
#   5,
#   10,
#   4,
#   285,
#   20,
#   36,
#   1690,
#   145,
#   6,
#   1,
#   281,
#   3,
#   1,
#   38,
#   40,
#   402,
#   1147,
#   588,
#   2,
#   5,
#   19,
#   7,
#   173,
#   2,
#   18,
#   1,
#   205,
#   22,
#   9,
#   403,
#   2,
#   7,
#   186,
#   86,
#   4,
#   589,
#   21,
#   694,
#   1691,
#   6,
#   168,
#   4,
#   221,
#   2,
#   32,
#   7,
#   109,
#   37,
#   590,
#   6,
#   9,
#   695,
#   40,
#   1148,
#   3,
#   27,
#   1,
#   238,
#   2,
#   12,
#   108,
#   2,
#   1149,
#   9,
#   188,
#   29,
#   9,
#   145,
#   3,
#   63,
#   314,
#   81,
#   315,
#   7,
#   1692,
#   2,
#   7,
#   85,
#   23,
#   259,
#   126,
#   3,
#   20,
#   189,
#   13,
#   206,
#   1150,
#   24,
#   26,
#   2,
#   207,
#   7,
#   11,
#   122,
#   4,
#   1693,
#   1694,
#   13,
#   7,
#   46,
#   23,
#   139,
#   6,
#   1695,
#   696,
#   2,
#   174,
#   32,
#   864,
#   1151,
#   3,
#   140,
#   162,
#   1696,
#   2,
#   238,
#   116,
#   6,
#   865,
#   7,
#   15,
#   312,
#   6,
#   13,
#   696,
#   3,
#   32,
#   7,
#   69,
#   81,
#   1143,
#   1,
#   156,
#   146,
#   60,
#   5,
#   81,
#   1,
#   239,
#   5,
#   1,
#   1697,
#   5,
#   33,
#   1,
#   99,
#   175,
#   173,
#   1698,
#   57,
#   2,
#   240,
#   1699,
#   6,
#   95,
#   866,
#   48,
#   11,
#   6,
#   41,
#   260,
#   2,
#   1,
#   238,
#   316,
#   25,
#   867,
#   5,
#   1700,
#   3,
#   7,
#   404,
#   6,
#   95,
#   1,
#   190,
#   225,
#   2,
#   5,
#   48,
#   7,
#   11,
#   18,
#   4,
#   188,
#   29,
#   9,
#   145,
#   5,
#   93,
#   457,
#   286,
#   13,
#   47,
#   352,
#   1152,
#   24,
#   118,
#   3,
#   28,
#   64,
#   7,
#   353,
#   4,
#   591,
#   8,
#   868,
#   5,
#   163,
#   42,
#   33,
#   9,
#   592,
#   3,
#   105,
#   85,
#   164,
#   12,
#   6,
#   95,
#   1,
#   190,
#   2,
#   30,
#   1,
#   868,
#   3,
#   125,
#   458,
#   8,
#   70,
#   405,
#   18,
#   65,
#   317,
#   5,
#   105,
#   82,
#   354,
#   12,
#   155,
#   34,
#   10,
#   1,
#   455,
#   113,
#   12,
#   85,
#   95,
#   1,
#   355,
#   1701,
#   3,
#   17,
#   191,
#   406,
#   176,
#   12,
#   82,
#   41,
#   1702,
#   3,
#   1,
#   238,
#   11,
#   25,
#   506,
#   226,
#   3,
#   7,
#   356,
#   1,
#   405,
#   1153,
#   18,
#   9,
#   317,
#   2,
#   1,
#   165,
#   868,
#   192,
#   458,
#   8,
#   14,
#   28,
#   22,
#   147,
#   318,
#   2,
#   5,
#   66,
#   20,
#   1703,
#   34,
#   227,
#   1,
#   1154,
#   3,
#   89,
#   51,
#   4,
#   287,
#   146,
#   57,
#   3,
#   7,
#   11,
#   25,
#   68,
#   1155,
#   22,
#   1,
#   593,
#   319,
#   5,
#   148,
#   157,
#   70,
#   208,
#   869,
#   41,
#   1,
#   133,
#   8,
#   1704,
#   31,
#   149,
#   594,
#   116,
#   1,
#   238,
#   3,
#   17,
#   19,
#   7,
#   697,
#   9,
#   507,
#   6,
#   189,
#   698,
#   209,
#   357,
#   7,
#   193,
#   9,
#   458,
#   29,
#   1,
#   405,
#   2,
#   5,
#   67,
#   7,
#   182,
#   6,
#   1,
#   258,
#   2,
#   113,
#   7,
#   11,
#   1156,
#   6,
#   699,
#   29,
#   4,
#   1157,
#   3,
#   27,
#   149,
#   10,
#   1,
#   190,
#   45,
#   12,
#   358,
#   1158,
#   158,
#   13,
#   53,
#   30,
#   4,
#   152,
#   700,
#   6,
#   54,
#   288,
#   3,
#   12,
#   109,
#   240,
#   358,
#   701,
#   1159,
#   18,
#   65,
#   702,
#   320,
#   35,
#   3,
#   289,
#   50,
#   81,
#   6,
#   358,
#   2,
#   152,
#   508,
#   2,
#   321,
#   1,
#   93,
#   700,
#   1705,
#   2,
#   16,
#   504,
#   6,
#   1160,
#   3,
#   26,
#   1,
#   106,
#   700,
#   261,
#   5,
#   261,
#   6,
#   358,
#   701,
#   1159,
#   3,
#   17,
#   71,
#   47,
#   358,
#   1158,
#   141,
#   2,
#   158,
#   54,
#   288,
#   3,
#   5,
#   32,
#   71,
#   404,
#   6,
#   359,
#   54,
#   702,
#   35,
#   71,
#   1706,
#   5,
#   182,
#   29,
#   54,
#   360,
#   3,
#   27,
#   55,
#   1161,
#   84,
#   67,
#   6,
#   4,
#   1707,
#   509,
#   6,
#   210,
#   3,
#   19,
#   7,
#   1708,
#   1162,
#   59,
#   1,
#   110,
#   2,
#   7,
#   1163,
#   4,
#   134,
#   228,
#   59,
#   1,
#   407,
#   3,
#   1,
#   106,
#   228,
#   83,
#   1164,
#   1,
#   93,
#   28,
#   5,
#   96,
#   9,
#   1165,
#   5,
#   1709,
#   49,
#   15,
#   361,
#   8,
#   24,
#   3,
#   4,
#   88,
#   459,
#   595,
#   2,
#   30,
#   28,
#   8,
#   42,
#   2,
#   1166,
#   29,
#   93,
#   1167,
#   18,
#   28,
#   8,
#   9,
#   362,
#   290,
#   31,
#   459,
#   2,
#   11,
#   7,
#   31,
#   30,
#   1,
#   106,
#   228,
#   2,
#   1168,
#   703,
#   34,
#   3,
#   11,
#   7,
#   19,
#   459,
#   19,
#   70,
#   53,
#   704,
#   2,
#   68,
#   510,
#   31,
#   20,
#   148,
#   3,
#   1,
#   228,
#   870,
#   34,
#   204,
#   114,
#   3,
#   7,
#   47,
#   23,
#   37,
#   76,
#   510,
#   119,
#   70,
#   2,
#   71,
#   30,
#   3,
#   17,
#   1,
#   93,
#   229,
#   33,
#   408,
#   13,
#   1,
#   595,
#   11,
#   68,
#   2,
#   68,
#   510,
#   5,
#   1,
#   106,
#   228,
#   223,
#   1168,
#   703,
#   35,
#   114,
#   5,
#   114,
#   262,
#   2,
#   33,
#   22,
#   102,
#   2,
#   71,
#   871,
#   3,
#   27,
#   4,
#   87,
#   5,
#   4,
#   194,
#   2,
#   58,
#   36,
#   1,
#   322,
#   8,
#   263,
#   2,
#   705,
#   25,
#   68,
#   6,
#   95,
#   323,
#   8,
#   1,
#   190,
#   3,
#   26,
#   20,
#   363,
#   6,
#   259,
#   1,
#   596,
#   5,
#   6,
#   291,
#   35,
#   59,
#   1,
#   190,
#   118,
#   1,
#   241,
#   13,
#   597,
#   6,
#   1,
#   264,
#   3,
#   1,
#   165,
#   511,
#   1710,
#   118,
#   10,
#   1,
#   25,
#   322,
#   8,
#   1169,
#   5,
#   177,
#   598,
#   142,
#   1170,
#   6,
#   599,
#   8,
#   3,
#   22,
#   1171,
#   1,
#   194,
#   2,
#   324,
#   21,
#   4,
#   195,
#   6,
#   1172,
#   2,
#   19,
#   11,
#   9,
#   1173,
#   2,
#   409,
#   1174,
#   4,
#   600,
#   120,
#   13,
#   7,
#   154,
#   46,
#   45,
#   25,
#   1175,
#   21,
#   4,
#   325,
#   40,
#   1711,
#   3,
#   1,
#   87,
#   47,
#   1712,
#   601,
#   5,
#   1,
#   194,
#   46,
#   460,
#   34,
#   29,
#   28,
#   8,
#   1,
#   706,
#   3,
#   26,
#   30,
#   2,
#   26,
#   292,
#   2,
#   5,
#   242,
#   ...]]

# %%
tokenized_texts = np.array(tokenized_texts).flatten()
tokenized_texts
# Out:
# array([ 48,  11, 102, ..., 596,   3,  27])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  ',': 2,
#  '.': 3,
#  'a': 4,
#  'and': 5,
#  'to': 6,
#  'he': 7,
#  'of': 8,
#  'his': 9,
#  'in': 10,
#  'was': 11,
#  'you': 12,
#  'that': 13,
#  'it': 14,
#  'had': 15,
#  'i': 16,
#  'but': 17,
#  'with': 18,
#  'as': 19,
#  'they': 20,
#  'for': 21,
#  'at': 22,
#  'not': 23,
#  'him': 24,
#  'very': 25,
#  'so': 26,
#  '|': 27,
#  'one': 28,
#  'on': 29,
#  'said': 30,
#  '!': 31,
#  'when': 32,
#  'all': 33,
#  'up': 34,
#  'out': 35,
#  'were': 36,
#  'have': 37,
#  'wolf': 38,
#  'fox': 39,
#  "'s": 40,
#  'be': 41,
#  'them': 42,
#  'is': 43,
#  'from': 44,
#  'do': 45,
#  'would': 46,
#  'could': 47,
#  'there': 48,
#  'what': 49,
#  'me': 50,
#  'then': 51,
#  'their': 52,
#  '?': 53,
#  'her': 54,
#  'an': 55,
#  'lion': 56,
#  'by': 57,
#  'who': 58,
#  'into': 59,
#  'about': 60,
#  'if': 61,
#  'ass': 62,
#  'no': 63,
#  'day': 64,
#  'your': 65,
#  'away': 66,
#  'down': 67,
#  'much': 68,
#  'saw': 69,
#  'this': 70,
#  'she': 71,
#  'mouse': 72,
#  'get': 73,
#  'did': 74,
#  'now': 75,
#  'been': 76,
#  'my': 77,
#  'time': 78,
#  'made': 79,
#  'are': 80,
#  'how': 81,
#  'will': 82,
#  'soon': 83,
#  'came': 84,
#  'can': 85,
#  'himself': 86,
#  'dog': 87,
#  'great': 88,
#  'just': 89,
#  'off': 90,
#  'am': 91,
#  'some': 92,
#  'little': 93,
#  'good': 94,
#  'see': 95,
#  'asked': 96,
#  'found': 97,
#  'head': 98,
#  'other': 99,
#  'let': 100,
#  'last': 101,
#  'once': 102,
#  'master': 103,
#  'well': 104,
#  'we': 105,
#  'old': 106,
#  'long': 107,
#  'know': 108,
#  'should': 109,
#  'water': 110,
#  'enough': 111,
#  'before': 112,
#  'where': 113,
#  'more': 114,
#  'eat': 115,
#  'began': 116,
#  'way': 117,
#  'along': 118,
#  'than': 119,
#  'tree': 120,
#  'man': 121,
#  'such': 122,
#  "n't": 123,
#  'which': 124,
#  'take': 125,
#  'home': 126,
#  'near': 127,
#  'farmer': 128,
#  'cat': 129,
#  'eagle': 130,
#  'again': 131,
#  'shepherd': 132,
#  'king': 133,
#  'young': 134,
#  'went': 135,
#  'got': 136,
#  'sheep': 137,
#  'while': 138,
#  'go': 139,
#  'after': 140,
#  'only': 141,
#  'any': 142,
#  'replied': 143,
#  'heard': 144,
#  'back': 145,
#  'flew': 146,
#  'each': 147,
#  'cried': 148,
#  'why': 149,
#  'among': 150,
#  'look': 151,
#  'mother': 152,
#  'over': 153,
#  'thought': 154,
#  'far': 155,
#  'birds': 156,
#  ':': 157,
#  'like': 158,
#  'around': 159,
#  'us': 160,
#  'first': 161,
#  'many': 162,
#  'told': 163,
#  'help': 164,
#  'two': 165,
#  'poor': 166,
#  'goat': 167,
#  'please': 168,
#  'make': 169,
#  ';': 170,
#  'monkey': 171,
#  'think': 172,
#  'ran': 173,
#  'even': 174,
#  'animals': 175,
#  'or': 176,
#  'without': 177,
#  'mice': 178,
#  'find': 179,
#  'come': 180,
#  'field': 181,
#  'fell': 182,
#  'hungry': 183,
#  'happened': 184,
#  'forest': 185,
#  'called': 186,
#  'knew': 187,
#  'house': 188,
#  'say': 189,
#  'world': 190,
#  'keep': 191,
#  'took': 192,
#  'lost': 193,
#  'cock': 194,
#  'place': 195,
#  'caught': 196,
#  'next': 197,
#  'here': 198,
#  'through': 199,
#  'left': 200,
#  'though': 201,
#  'every': 202,
#  'sun': 203,
#  'still': 204,
#  'dogs': 205,
#  'jupiter': 206,
#  'because': 207,
#  'must': 208,
#  'foolish': 209,
#  'drink': 210,
#  'tell': 211,
#  'sure': 212,
#  'feathers': 213,
#  'put': 214,
#  'may': 215,
#  'fine': 216,
#  'family': 217,
#  'own': 218,
#  'nothing': 219,
#  'bear': 220,
#  'kid': 221,
#  'evening': 222,
#  'kept': 223,
#  'right': 224,
#  'too': 225,
#  'indeed': 226,
#  'toward': 227,
#  'frog': 228,
#  'frogs': 229,
#  'wings': 230,
#  'claws': 231,
#  'nest': 232,
#  'stood': 233,
#  'lay': 234,
#  'walked': 235,
#  'looked': 236,
#  'flock': 237,
#  'tortoise': 238,
#  'hare': 239,
#  'always': 240,
#  'road': 241,
#  'both': 242,
#  'might': 243,
#  'run': 244,
#  'lived': 245,
#  'lamb': 246,
#  'country': 247,
#  'food': 248,
#  'life': 249,
#  'morning': 250,
#  'most': 251,
#  'upon': 252,
#  'quickly': 253,
#  'goats': 254,
#  'together': 255,
#  'cave': 256,
#  'horns': 257,
#  'ground': 258,
#  'leave': 259,
#  'seen': 260,
#  'tried': 261,
#  'until': 262,
#  'friends': 263,
#  'woods': 264,
#  'shall': 265,
#  'kind': 266,
#  'running': 267,
#  'boy': 268,
#  'easily': 269,
#  'loudly': 270,
#  'tail': 271,
#  'ever': 272,
#  'anything': 273,
#  'stork': 274,
#  'gold': 275,
#  'another': 276,
#  'honey': 277,
#  'eggs': 278,
#  'axe': 279,
#  'care': 280,
#  'pasture': 281,
#  'wind': 282,
#  'making': 283,
#  'going': 284,
#  'moment': 285,
#  'legs': 286,
#  'crow': 287,
#  'son': 288,
#  'show': 289,
#  'feet': 290,
#  'set': 291,
#  'done': 292,
#  'immediately': 293,
#  'our': 294,
#  'door': 295,
#  'plan': 296,
#  'themselves': 297,
#  'neck': 298,
#  'large': 299,
#  'carrying': 300,
#  'bird': 301,
#  'give': 302,
#  'yes': 303,
#  'try': 304,
#  'being': 305,
#  'work': 306,
#  'begged': 307,
#  'days': 308,
#  'under': 309,
#  'three': 310,
#  'traveler': 311,
#  'gone': 312,
#  'carried': 313,
#  'matter': 314,
#  'hard': 315,
#  'felt': 316,
#  'teeth': 317,
#  'end': 318,
#  'sight': 319,
#  'turned': 320,
#  'answered': 321,
#  'best': 322,
#  'something': 323,
#  'looking': 324,
#  'night': 325,
#  'quite': 326,
#  'least': 327,
#  'its': 328,
#  'ate': 329,
#  'meal': 330,
#  'bit': 331,
#  'beautiful': 332,
#  'ready': 333,
#  'side': 334,
#  'top': 335,
#  'bull': 336,
#  'people': 337,
#  'proudly': 338,
#  'passed': 339,
#  'instant': 340,
#  'fast': 341,
#  'beasts': 342,
#  'better': 343,
#  'bat': 344,
#  'dinner': 345,
#  'stag': 346,
#  'weasel': 347,
#  'woodman': 348,
#  'able': 349,
#  'later': 350,
#  'feast': 351,
#  'hardly': 352,
#  'met': 353,
#  'carry': 354,
#  'whole': 355,
#  'seized': 356,
#  'words': 357,
#  'walk': 358,
#  'turn': 359,
#  'nose': 360,
#  'become': 361,
#  'huge': 362,
#  'decided': 363,
#  'instead': 364,
#  'gave': 365,
#  'call': 366,
#  'father': 367,
#  'single': 368,
#  'wheat': 369,
#  'seemed': 370,
#  'sat': 371,
#  'bone': 372,
#  'course': 373,
#  'reach': 374,
#  'strength': 375,
#  'besides': 376,
#  'paw': 377,
#  'creature': 378,
#  'voice': 379,
#  'laughed': 380,
#  'village': 381,
#  'horn': 382,
#  'same': 383,
#  'cranes': 384,
#  'company': 385,
#  "'": 386,
#  'reeds': 387,
#  'owl': 388,
#  'grew': 389,
#  'grasshopper': 390,
#  'eyes': 391,
#  'returned': 392,
#  'bank': 393,
#  'fish': 394,
#  'treasure': 395,
#  'number': 396,
#  'basket': 397,
#  'brought': 398,
#  'part': 399,
#  'mercury': 400,
#  'started': 401,
#  'song': 402,
#  'heels': 403,
#  'wanted': 404,
#  'stick': 405,
#  'quiet': 406,
#  'mud': 407,
#  'declared': 408,
#  'spied': 409,
#  'feel': 410,
#  'enemy': 411,
#  'coming': 412,
#  'fear': 413,
#  'yet': 414,
#  'wagon': 415,
#  'against': 416,
#  'cold': 417,
#  'table': 418,
#  'distance': 419,
#  'sons': 420,
#  'crane': 421,
#  'mountain': 422,
#  'thinking': 423,
#  'drive': 424,
#  'small': 425,
#  'settled': 426,
#  'walking': 427,
#  'fat': 428,
#  'hands': 429,
#  'hurt': 430,
#  'log': 431,
#  'oak': 432,
#  'times': 433,
#  'pond': 434,
#  'live': 435,
#  'safety': 436,
#  'neighbors': 437,
#  'race': 438,
#  'battle': 439,
#  'rich': 440,
#  'shore': 441,
#  'catch': 442,
#  'held': 443,
#  'skin': 444,
#  'wait': 445,
#  'search': 446,
#  'save': 447,
#  'carefully': 448,
#  'golden': 449,
#  'whose': 450,
#  'mr.': 451,
#  'dance': 452,
#  'idea': 453,
#  'struck': 454,
#  'air': 455,
#  'ears': 456,
#  'short': 457,
#  'hold': 458,
#  'big': 459,
#  'fly': 460,
#  'sir': 461,
#  'foot': 462,
#  'none': 463,
#  'jackdaw': 464,
#  'filled': 465,
#  'deep': 466,
#  'harm': 467,
#  'edge': 468,
#  'town': 469,
#  'talk': 470,
#  'hiding': 471,
#  'high': 472,
#  'fall': 473,
#  'certain': 474,
#  'cast': 475,
#  'greedy': 476,
#  'pull': 477,
#  'laid': 478,
#  'rest': 479,
#  'men': 480,
#  'market': 481,
#  'sent': 482,
#  'wise': 483,
#  'heads': 484,
#  'pride': 485,
#  'river': 486,
#  'drove': 487,
#  'fight': 488,
#  'wild': 489,
#  'danger': 490,
#  'close': 491,
#  "'ve": 492,
#  'things': 493,
#  'wolves': 494,
#  'meat': 495,
#  'open': 496,
#  'has': 497,
#  'judge': 498,
#  'pot': 499,
#  'dead': 500,
#  'beetle': 501,
#  'kite': 502,
#  'grass': 503,
#  'want': 504,
#  'slowly': 505,
#  'glad': 506,
#  'mouth': 507,
#  'dear': 508,
#  'pool': 509,
#  'bigger': 510,
#  'comrades': 511,
#  'wood': 512,
#  'delicious': 513,
#  'breakfast': 514,
#  'plans': 515,
#  'simple': 516,
#  'hear': 517,
#  'strong': 518,
#  'noticed': 519,
#  'load': 520,
#  'really': 521,
#  'yourself': 522,
#  'served': 523,
#  'city': 524,
#  'friend': 525,
#  'stopped': 526,
#  'jumped': 527,
#  'vain': 528,
#  'worth': 529,
#  'nor': 530,
#  'thing': 531,
#  'angrily': 532,
#  'spare': 533,
#  'amused': 534,
#  'angry': 535,
#  'trick': 536,
#  'few': 537,
#  'behind': 538,
#  'spring': 539,
#  'gnat': 540,
#  'discovered': 541,
#  'makes': 542,
#  'purse': 543,
#  'thief': 544,
#  'honor': 545,
#  'milk': 546,
#  'new': 547,
#  'sky': 548,
#  'kindly': 549,
#  'wonderful': 550,
#  'shadow': 551,
#  "'ll": 552,
#  'rat': 553,
#  'hide': 554,
#  'fun': 555,
#  'death': 556,
#  'narrow': 557,
#  'bright': 558,
#  'bite': 559,
#  'black': 560,
#  'almost': 561,
#  'died': 562,
#  'meet': 563,
#  'stung': 564,
#  'rage': 565,
#  'succeeded': 566,
#  'chance': 567,
#  'frightened': 568,
#  'agreed': 569,
#  'getting': 570,
#  'early': 571,
#  'buy': 572,
#  'never': 573,
#  'divide': 574,
#  'swam': 575,
#  'bees': 576,
#  'beak': 577,
#  'news': 578,
#  'swallow': 579,
#  'countryman': 580,
#  'laugh': 581,
#  'ant': 582,
#  'miller': 583,
#  'cloak': 584,
#  'tender': 585,
#  'terrible': 586,
#  'eating': 587,
#  'suddenly': 588,
#  'fool': 589,
#  'stuck': 590,
#  'pair': 591,
#  'trouble': 592,
#  'strange': 593,
#  'certainly': 594,
#  'monster': 595,
#  'farmyard': 596,
#  'led': 597,
#  'meeting': 598,
#  'speak': 599,
#  'hollow': 600,
#  'inside': 601,
#  'politely': 602,
#  'deed': 603,
#  'guessed': 604,
#  'hand': 605,
#  'unable': 606,
#  'satisfied': 607,
#  'heavy': 608,
#  'climbed': 609,
#  'beside': 610,
#  'move': 611,
#  'lesson': 612,
#  'learned': 613,
#  'visited': 614,
#  'manner': 615,
#  'sleep': 616,
#  'imagine': 617,
#  'clear': 618,
#  'followed': 619,
#  'leap': 620,
#  'pulled': 621,
#  'use': 622,
#  'loud': 623,
#  'weight': 624,
#  'watching': 625,
#  'villagers': 626,
#  'dropped': 627,
#  'tip': 628,
#  'shade': 629,
#  'creatures': 630,
#  'escape': 631,
#  'prize': 632,
#  'picked': 633,
#  'stop': 634,
#  'threw': 635,
#  'summer': 636,
#  'else': 637,
#  'sharp': 638,
#  'stay': 639,
#  'sing': 640,
#  'exclaimed': 641,
#  'blow': 642,
#  'stand': 643,
#  'north': 644,
#  'stones': 645,
#  'grain': 646,
#  'surprise': 647,
#  'bray': 648,
#  'white': 649,
#  'chanced': 650,
#  'finished': 651,
#  'afraid': 652,
#  'deal': 653,
#  'hoofs': 654,
#  'quarrel': 655,
#  'drinking': 656,
#  'stream': 657,
#  'someone': 658,
#  'fellow': 659,
#  'outside': 660,
#  'fisherman': 661,
#  'weasels': 662,
#  'return': 663,
#  'several': 664,
#  'also': 665,
#  'climb': 666,
#  'between': 667,
#  'rabbit': 668,
#  'swarm': 669,
#  'looks': 670,
#  'heron': 671,
#  'pointed': 672,
#  'corner': 673,
#  'trying': 674,
#  'child': 675,
#  'attention': 676,
#  'sooner': 677,
#  'earthen': 678,
#  'goose': 679,
#  'money': 680,
#  'those': 681,
#  'hole': 682,
#  'serpent': 683,
#  'sell': 684,
#  'stone': 685,
#  'miser': 686,
#  'case': 687,
#  'trap': 688,
#  'foxes': 689,
#  'snakes': 690,
#  'satyr': 691,
#  'shadows': 692,
#  'homeward': 693,
#  'turning': 694,
#  'butcher': 695,
#  'wedding': 696,
#  'opened': 697,
#  'these': 698,
#  'pieces': 699,
#  'crab': 700,
#  'straight': 701,
#  'toes': 702,
#  'herself': 703,
#  'oh': 704,
#  'wished': 705,
#  'branches': 706,
#  'forgot': 707,
#  'decide': 708,
#  'fortune': 709,
#  'arose': 710,
#  'ask': 711,
#  'silly': 712,
#  'rise': 713,
#  'children': 714,
#  'pitcher': 715,
#  'taken': 716,
#  'perhaps': 717,
#  'wheels': 718,
#  'effort': 719,
#  'bad': 720,
#  'saying': 721,
#  'content': 722,
#  'gladly': 723,
#  'hurried': 724,
#  'peace': 725,
#  'grapes': 726,
#  'hung': 727,
#  'disgust': 728,
#  'bundle': 729,
#  'break': 730,
#  'stronger': 731,
#  'throat': 732,
#  'neither': 733,
#  'bill': 734,
#  'anxiously': 735,
#  'beast': 736,
#  'oxen': 737,
#  'loaded': 738,
#  'different': 739,
#  'light': 740,
#  'resting': 741,
#  'kill': 742,
#  'prey': 743,
#  'bound': 744,
#  'play': 745,
#  'attack': 746,
#  'shouting': 747,
#  'terror': 748,
#  'killed': 749,
#  'slipped': 750,
#  'meadow': 751,
#  'having': 752,
#  'leaves': 753,
#  'useless': 754,
#  'whatever': 755,
#  'thus': 756,
#  'visit': 757,
#  'share': 758,
#  'pig': 759,
#  'traveling': 760,
#  'full': 761,
#  'travelers': 762,
#  'quietly': 763,
#  'tired': 764,
#  'gods': 765,
#  'warm': 766,
#  'aside': 767,
#  'spoke': 768,
#  'enjoy': 769,
#  'appetite': 770,
#  'fit': 771,
#  'arms': 772,
#  'blows': 773,
#  'rushed': 774,
#  'proud': 775,
#  'elephant': 776,
#  'flying': 777,
#  'means': 778,
#  'weather': 779,
#  'thirsty': 780,
#  'die': 781,
#  'rose': 782,
#  'winter': 783,
#  'doing': 784,
#  'knees': 785,
#  'became': 786,
#  'stupid': 787,
#  'merchant': 788,
#  'seashore': 789,
#  'delighted': 790,
#  'dragged': 791,
#  'worn': 792,
#  'pleased': 793,
#  'camel': 794,
#  'gathered': 795,
#  'boar': 796,
#  'hidden': 797,
#  'constantly': 798,
#  'cheese': 799,
#  'promise': 800,
#  'ca': 801,
#  'claw': 802,
#  'since': 803,
#  'hunting': 804,
#  'bones': 805,
#  'appearance': 806,
#  'smell': 807,
#  'lick': 808,
#  'tricks': 809,
#  'safe': 810,
#  'peacock': 811,
#  'despair': 812,
#  'army': 813,
#  'beaten': 814,
#  'escaped': 815,
#  'prowling': 816,
#  'yard': 817,
#  'eaten': 818,
#  'whom': 819,
#  'known': 820,
#  'neighborhood': 821,
#  'peacocks': 822,
#  'dress': 823,
#  'dressed': 824,
#  'dolphin': 825,
#  'feeding': 826,
#  'fire': 827,
#  'bee': 828,
#  'sprang': 829,
#  'leopard': 830,
#  'wits': 831,
#  'face': 832,
#  'watched': 833,
#  'belonged': 834,
#  'marsh': 835,
#  'living': 836,
#  'expect': 837,
#  'thank': 838,
#  'hen': 839,
#  'ago': 840,
#  'stars': 841,
#  'silver': 842,
#  'everybody': 843,
#  'eagerly': 844,
#  'rolled': 845,
#  'flies': 846,
#  'toad': 847,
#  'cure': 848,
#  'hounds': 849,
#  'longer': 850,
#  'butterfly': 851,
#  'constancy': 852,
#  'wasps': 853,
#  'ride': 854,
#  'dove': 855,
#  'paid': 856,
#  'nibbling': 857,
#  'alone': 858,
#  'creeping': 859,
#  'trembling': 860,
#  'tune': 861,
#  'music': 862,
#  'leaped': 863,
#  'especially': 864,
#  'wish': 865,
#  'everything': 866,
#  'sad': 867,
#  'ducks': 868,
#  'surely': 869,
#  'puffed': 870,
#  'burst': 871,
#  'slept': 872,
#  'standing': 873,
#  'crowed': 874,
#  'rosy': 875,
#  'hurrying': 876,
#  'porter': 877,
#  'twinkling': 878,
#  'free': 879,
#  'dared': 880,
#  'hang': 881,
#  'bell': 882,
#  'ram': 883,
#  'given': 884,
#  'cry': 885,
#  'half': 886,
#  'horses': 887,
#  'sank': 888,
#  'hercules': 889,
#  'appear': 890,
#  'simply': 891,
#  'unless': 892,
#  'roof': 893,
#  'talking': 894,
#  'stalks': 895,
#  'plain': 896,
#  'rather': 897,
#  'talked': 898,
#  'reached': 899,
#  'den': 900,
#  'bunch': 901,
#  'ripe': 902,
#  'jump': 903,
#  'myself': 904,
#  'scornfully': 905,
#  'mind': 906,
#  'lead': 907,
#  'usual': 908,
#  'bring': 909,
#  'agree': 910,
#  'reward': 911,
#  'snarled': 912,
#  'driven': 913,
#  'cliff': 914,
#  'tumbled': 915,
#  'complain': 916,
#  'sort': 917,
#  'pulling': 918,
#  'fright': 919,
#  'across': 920,
#  'tiny': 921,
#  'generous': 922,
#  'hunter': 923,
#  'net': 924,
#  'roaring': 925,
#  'ropes': 926,
#  'amuse': 927,
#  'buzzing': 928,
#  'used': 929,
#  'plane': 930,
#  'o': 931,
#  'pleaded': 932,
#  'punishment': 933,
#  'behavior': 934,
#  'often': 935,
#  'ashamed': 936,
#  'lucky': 937,
#  "'i": 938,
#  'shout': 939,
#  'flash': 940,
#  'government': 941,
#  'fearful': 942,
#  'diving': 943,
#  'teach': 944,
#  'ruler': 945,
#  'cruel': 946,
#  'takes': 947,
#  'hunt': 948,
#  'opening': 949,
#  'window': 950,
#  'argue': 951,
#  'anybody': 952,
#  'punish': 953,
#  'settle': 954,
#  'entirely': 955,
#  'bowed': 956,
#  'fought': 957,
#  'grand': 958,
#  'procession': 959,
#  'gorgeous': 960,
#  'royal': 961,
#  'crowd': 962,
#  'forget': 963,
#  'clumsy': 964,
#  'boys': 965,
#  'bravest': 966,
#  'picking': 967,
#  'ants': 968,
#  'sunshine': 969,
#  'stored': 970,
#  'swan': 971,
#  'swimming': 972,
#  'washed': 973,
#  'fallen': 974,
#  'middle': 975,
#  'below': 976,
#  'salt': 977,
#  'crossed': 978,
#  'shallow': 979,
#  'ford': 980,
#  'fiercely': 981,
#  'tearing': 982,
#  'victory': 983,
#  'rhodes': 984,
#  'true': 985,
#  'need': 986,
#  'witnesses': 987,
#  'clever': 988,
#  'ridiculous': 989,
#  'kicked': 990,
#  'within': 991,
#  'disgusted': 992,
#  'ribs': 993,
#  'chicken': 994,
#  'taking': 995,
#  'cause': 996,
#  'hides': 997,
#  'stray': 998,
#  'furiously': 999,
#  'farther': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)+1
vocab_size
# Out:
# 3076

# %% [markdown]
# ## Loading GloVe and creating embedding matrix

# %%
PATH = '../input/glove-global-vectors-for-'\
        'word-representation/glove.6B.100d.txt'

glove = pd.read_table(PATH, sep=" ", 
                      index_col=0, header=None, 
                      quoting=csv.QUOTE_NONE)

# %%
glove.head()
# Out:
#           1         2        3         4         5         6         7    \
# 0
# the -0.038194 -0.244870  0.72812 -0.399610  0.083172  0.043953 -0.391410
# ,   -0.107670  0.110530  0.59812 -0.543610  0.673960  0.106630  0.038867
# .   -0.339790  0.209410  0.46348 -0.647920 -0.383770  0.038034  0.171270
# of  -0.152900 -0.242790  0.89837  0.169960  0.535160  0.487840 -0.588260
# to  -0.189700  0.050024  0.19084 -0.049184 -0.089737  0.210060 -0.549520
#
#           8        9         10   ...       91        92        93       94   \
# 0                                 ...
# the  0.334400 -0.57545  0.087459  ...  0.016215 -0.017099 -0.389840  0.87424
# ,    0.354810  0.06351 -0.094189  ...  0.349510 -0.722600  0.375490  0.44410
# .    0.159780  0.46619 -0.019169  ... -0.063351 -0.674120 -0.068895  0.53604
# of  -0.179820 -1.35810  0.425410  ...  0.187120 -0.018488 -0.267570  0.72700
# to   0.098377 -0.20135  0.342410  ... -0.131340  0.058617 -0.318690 -0.61419
#
#          95       96        97       98       99        100
# 0
# the -0.72569 -0.51058 -0.520280 -0.14590  0.82780  0.270620
# ,   -0.99059  0.61214 -0.351110 -0.83155  0.45293  0.082577
# .   -0.87773  0.31802 -0.392420 -0.23394  0.47298 -0.028803
# of  -0.59363 -0.34839 -0.560940 -0.59100  1.00390  0.206640
# to  -0.62393 -0.41548 -0.038175 -0.39804  0.47647 -0.159830
#
# [5 rows x 100 columns]

# %%
glove.shape
# Out:
# (400000, 100)

# %%
embedding_matrix = np.zeros((vocab_size,100))
for word, i in tqdm(tokenizer.word_index.items()):
    try:
        embedding_vector = glove.loc[word].values
    except KeyError:
        pass
    embedding_matrix[i] = embedding_vector
    
    # e.g. The word "the" will be placed at index 1
# Out:
# 100%|██████████| 3075/3075 [01:00<00:00, 50.80it/s]

# %% [markdown]
# ## Determine predictor variables (X) and the target (y)

# %%
X = []
y = []
for i in range(len(tokenized_texts)):
    if i+20 < len(tokenized_texts):
        start = i
        end = i+20

        X.append(tokenized_texts[start:end])
        y.append(tokenized_texts[end])
        
X = np.array(X)
y = np.array(y)

# %% [markdown]
# ## Convert target to categorical data (one-hot encoding)

# %%
y_one_hot = to_categorical(y, num_classes=vocab_size)
y_one_hot.shape
# Out:
# (27415, 3076)

# %% [markdown]
# ## Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, 
                                                    test_size=0.2, 
                                                    random_state=99)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (21932, 20)
# (5483, 20)

# %% [markdown]
# ## Construct the LSTM-based neural network model

# %%
lstm_input = Input(shape=(None,))
lstm = Embedding(input_dim=vocab_size, 
                 output_dim=100, 
                 weights=[embedding_matrix],
                 trainable=True)(lstm_input)
lstm = LSTM(256)(lstm)
lstm_output = Dense(vocab_size, activation='softmax')(lstm)

# %%
model = Model(lstm_input, lstm_output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 100)         307600
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               365568
# _________________________________________________________________
# dense (Dense)                (None, 3076)              790532
# =================================================================
# Total params: 1,463,700
# Trainable params: 1,463,700
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['acc'])

# %%
history = model.fit(X_train, y_train, 
                    epochs=20, batch_size=32, 
                    validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# 686/686 [==============================] - 15s 13ms/step - loss: 6.2579 - acc: 0.0788 - val_loss: 5.5625 - val_acc: 0.1195
# Epoch 2/20
# 686/686 [==============================] - 8s 11ms/step - loss: 5.2584 - acc: 0.1273 - val_loss: 5.2558 - val_acc: 0.1472
# Epoch 3/20
# 686/686 [==============================] - 8s 11ms/step - loss: 4.6831 - acc: 0.1633 - val_loss: 5.1764 - val_acc: 0.1547
# Epoch 4/20
# 686/686 [==============================] - 7s 11ms/step - loss: 4.2549 - acc: 0.1880 - val_loss: 5.1586 - val_acc: 0.1672
# Epoch 5/20
# 686/686 [==============================] - 8s 12ms/step - loss: 3.8556 - acc: 0.2244 - val_loss: 5.1889 - val_acc: 0.1720
# Epoch 6/20
# 686/686 [==============================] - 8s 11ms/step - loss: 3.4737 - acc: 0.2667 - val_loss: 5.2575 - val_acc: 0.1740
# Epoch 7/20
# 686/686 [==============================] - 8s 11ms/step - loss: 3.1171 - acc: 0.3141 - val_loss: 5.3770 - val_acc: 0.1736
# Epoch 8/20
# 686/686 [==============================] - 8s 11ms/step - loss: 2.7080 - acc: 0.3875 - val_loss: 5.5105 - val_acc: 0.1722
# Epoch 9/20
# 686/686 [==============================] - 8s 12ms/step - loss: 2.3556 - acc: 0.4675 - val_loss: 5.6231 - val_acc: 0.1643
# Epoch 10/20
# 686/686 [==============================] - 7s 11ms/step - loss: 2.0053 - acc: 0.5517 - val_loss: 5.7930 - val_acc: 0.1620
# Epoch 11/20
# 686/686 [==============================] - 8s 11ms/step - loss: 1.7011 - acc: 0.6236 - val_loss: 5.9423 - val_acc: 0.1601
# Epoch 12/20
# 686/686 [==============================] - 8s 11ms/step - loss: 1.4282 - acc: 0.6969 - val_loss: 6.1101 - val_acc: 0.1541
# Epoch 13/20
# 686/686 [==============================] - 8s 12ms/step - loss: 1.1734 - acc: 0.7633 - val_loss: 6.2863 - val_acc: 0.1516
# Epoch 14/20
# 686/686 [==============================] - 7s 11ms/step - loss: 0.9591 - acc: 0.8162 - val_loss: 6.4812 - val_acc: 0.1461
# Epoch 15/20
# 686/686 [==============================] - 8s 11ms/step - loss: 0.7596 - acc: 0.8672 - val_loss: 6.6664 - val_acc: 0.1419
# Epoch 16/20
# 686/686 [==============================] - 7s 11ms/step - loss: 0.5977 - acc: 0.9065 - val_loss: 6.8686 - val_acc: 0.1410
# Epoch 17/20
# 686/686 [==============================] - 8s 11ms/step - loss: 0.4589 - acc: 0.9386 - val_loss: 7.0187 - val_acc: 0.1395
# Epoch 18/20
# 686/686 [==============================] - 8s 11ms/step - loss: 0.3448 - acc: 0.9622 - val_loss: 7.2294 - val_acc: 0.1386
# Epoch 19/20
# 686/686 [==============================] - 8s 11ms/step - loss: 0.2552 - acc: 0.9781 - val_loss: 7.4511 - val_acc: 0.1361
# Epoch 20/20
# 686/686 [==============================] - 7s 11ms/step - loss: 0.1870 - acc: 0.9892 - val_loss: 7.6144 - val_acc: 0.1357

# %% [markdown]
# ## Function to tell the neural network to write

# %%
def write(text):
    while text[-1] != '|':
        # Preprocessing
        text = preprocess(text)
        tokenized_text = tokenizer.texts_to_sequences([text])
        tokenized_text = np.array(tokenized_text).flatten()
        
        # Predicting the next word
        pred_one_hot = model.predict(np.array([tokenized_text]))
        pred_token = np.argmax(pred_one_hot)
        
        # Decoding the predicted word
        pred_text = tokenizer.sequences_to_texts([[pred_token]])
        
        # Decoding the previous words
        text = tokenizer.sequences_to_texts([tokenized_text])

        # Concatenating the previous words and the new word
        text = text[0]+' '+pred_text[0]
        
    return text

# %%
sentence = 'I am so hungry'
write(sentence)
# Out:
# 'i am so hungry ! last he asked with a laugh when he had hired the ass and had made him had to eat himself , and his head and his son came down down the stag , and rising on his hind legs , and began a wild dance . first he whirled round and saw that all his strength were in a different sort of silver . |'
